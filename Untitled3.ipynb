# %% [markdown]
# <a href="https://colab.research.google.com/github/DivamSanghvi/MoodMusic-Webscraping/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.1.0-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.2.3)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2024.8.30)
# Downloading spotipy-2.24.0-py3-none-any.whl (30 kB)
# Downloading redis-5.1.0-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.1.0 spotipy-2.24.0

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import os
import time
from spotipy.exceptions import SpotifyException

# Spotify API credentials
client_id = ''
client_secret = ''

# Authentication
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Function to get top tracks of an artist
def get_artist_top_tracks(artist_name):
    try:
        results = sp.search(q='artist:' + artist_name, type='artist')
        items = results['artists']['items']
        if len(items) > 0:
            artist = items[0]
            artist_id = artist['id']
            top_tracks = sp.artist_top_tracks(artist_id)
            return top_tracks['tracks'], artist['genres']  # Returning artist genres as well
    except Exception as e:
        print(f"Error fetching top tracks for {artist_name}: {e}")
    return [], []

# Function to get audio features for multiple tracks
def get_tracks_features(track_ids):
    while True:
        try:
            features = sp.audio_features(track_ids)
            return features
        except SpotifyException as e:
            if e.http_status == 429:  # Rate limit exceeded
                print("Rate limit exceeded. Retrying after 15 seconds...")
                time.sleep(15)  # Increased wait time to 15 seconds
            else:
                print(f"Error fetching track features: {e}")
                return None  # Return None if any error occurs

# Function to validate track features and return a default value if missing
def validate_feature(feature, default_value=0):
    return feature if feature is not None else default_value

# Function to scrape data for an artist
def scrape_artist_data(artist_name):
    tracks, genres = get_artist_top_tracks(artist_name)
    data = []
    track_ids = [track['id'] for track in tracks]

    if track_ids:
        # Fetch features for all tracks at once
        features_list = get_tracks_features(track_ids)

        if features_list is not None:
            for track, features in zip(tracks, features_list):
                if features:  # Check if features exist
                    album = track['album']  # Getting album info
                    data.append({
                        'song_id': track['id'],
                        'artist_name': artist_name,
                        'track_name': track['name'],
                        'album_name': album['name'],  # Album name
                        'album_release_date': album['release_date'],  # Release date
                        'genres': ', '.join(genres) if genres else 'Unknown',  # List of genres, default to 'Unknown'
                        'valence': validate_feature(features.get('valence')),
                        'energy': validate_feature(features.get('energy')),
                        'danceability': validate_feature(features.get('danceability')),
                        'loudness': validate_feature(features.get('loudness')),
                        'tempo': validate_feature(features.get('tempo')),
                        'speechiness': validate_feature(features.get('speechiness')),
                        'instrumentalness': validate_feature(features.get('instrumentalness')),
                        'popularity': validate_feature(track.get('popularity'))
                    })
    return data

# Function to scrape the top artists from a playlist or a generic search (to mimic top 1000 artists)
def get_top_artists(limit=1000):
    all_artists = []
    offset = 0
    while len(all_artists) < limit:
        try:
            results = sp.search(q="genre:pop", type="artist", limit=50, offset=offset)  # Get 50 artists at a time
            artists = results['artists']['items']
            if not artists:
                break  # Stop if no more artists are found
            all_artists.extend([artist['name'] for artist in artists])
            offset += 50  # Move to the next batch
            time.sleep(1)  # Delay to avoid hitting the rate limit
        except Exception as e:
            print(f"Error fetching top artists: {e}")
            break
    return all_artists[:limit]  # Return only up to the requested limit

# Function to save data to a CSV file
def save_data_to_csv(data, filename='spotify_data.csv'):
    df = pd.DataFrame(data)
    file_exists = os.path.isfile(filename)
    # Write to CSV (append if exists)
    df.to_csv(filename, mode='a', header=not file_exists, index=False)
    print(f"Data saved to {filename}")

# Main function
def main():
    artists = get_top_artists(limit=1000)
    all_data = []
    try:
        # Scrape data for all artists
        for artist in artists:
            print(f"Scraping data for {artist}...")
            artist_data = scrape_artist_data(artist)
            all_data.extend(artist_data)

        # Save the final data
        save_data_to_csv(all_data)

    except Exception as e:
        # Save the data even if an error occurs
        print(f"Error occurred: {e}. Saving the data scraped until now.")
        save_data_to_csv(all_data)

if __name__ == "__main__":
    main()
# Out:
# Scraping data for Taylor Swift...
# Scraping data for Drake...
# Scraping data for Sabrina Carpenter...
# Scraping data for Post Malone...
# Scraping data for The Weeknd...
# Scraping data for Billie Eilish...
# Scraping data for Chappell Roan...
# Scraping data for SZA...
# Scraping data for Bruno Mars...
# Scraping data for Noah Kahan...
# Scraping data for Lana Del Rey...
# Scraping data for Rihanna...
# Scraping data for Ariana Grande...
# Scraping data for Lil Wayne...
# Scraping data for Charli xcx...
# Scraping data for Lady Gaga...
# Scraping data for Hozier...
# Scraping data for Olivia Rodrigo...
# Scraping data for Nicki Minaj...
# Scraping data for Justin Bieber...
# Scraping data for Feid...
# Scraping data for Coldplay...
# Scraping data for Rauw Alejandro...
# Scraping data for Jelly Roll...
# Scraping data for Beyoncé...
# Scraping data for Doja Cat...
# Scraping data for Kali Uchis...
# Scraping data for Benson Boone...
# Scraping data for Imagine Dragons...
# Scraping data for Ty Dolla $ign...
# Scraping data for David Guetta...
# Scraping data for Jimin...
# Scraping data for Khalid...
# Scraping data for Megan Thee Stallion...
# Scraping data for Tate McRae...
# Scraping data for Katy Perry...
# Scraping data for JAY-Z...
# Scraping data for Dua Lipa...
# Scraping data for Lil Durk...
# Scraping data for The Neighbourhood...
# Scraping data for Ed Sheeran...
# Scraping data for Calvin Harris...
# Scraping data for Clairo...
# Scraping data for Cigarettes After Sex...
# Scraping data for Pitbull...
# Scraping data for Maroon 5...
# Scraping data for Twenty One Pilots...
# Scraping data for Adele...
# Scraping data for Marshmello...
# Scraping data for USHER...
# Scraping data for Ozuna...
# Scraping data for Tory Lanez...
# Scraping data for Snoop Dogg...
# Scraping data for 50 Cent...
# Scraping data for beabadoobee...
# Scraping data for Harry Styles...
# Scraping data for BTS...
# Scraping data for OneRepublic...
# Scraping data for Shaboozey...
# Scraping data for Kid Cudi...
# Scraping data for Justin Timberlake...
# Scraping data for Stray Kids...
# Scraping data for Shakira...
# Scraping data for Wiz Khalifa...
# Scraping data for The Lumineers...
# Scraping data for Cody Johnson...
# Scraping data for Big Sean...
# Scraping data for Halsey...
# Scraping data for Miley Cyrus...
# Scraping data for DaBaby...
# Scraping data for Fall Out Boy...
# Scraping data for Jung Kook...
# Scraping data for T-Pain...
# Scraping data for mgk...
# Scraping data for Romeo Santos...
# Scraping data for Lainey Wilson...
# Scraping data for blink-182...
# Scraping data for Megan Moroney...
# Scraping data for HARDY...
# Scraping data for Cardi B...
# Scraping data for Maluma...
# Scraping data for Dominic Fike...
# Scraping data for One Direction...
# Scraping data for Offset...
# Scraping data for NF...
# Scraping data for Koe Wetzel...
# Scraping data for Bailey Zimmerman...
# Scraping data for Tiësto...
# Scraping data for Pharrell Williams...
# Scraping data for Phoebe Bridgers...
# Scraping data for Akon...
# Scraping data for Sam Smith...
# Scraping data for Treaty Oak Revival...
# Scraping data for Ne-Yo...
# Scraping data for Britney Spears...
# Scraping data for Riley Green...
# Scraping data for Paramore...
# Scraping data for Glass Animals...
# Scraping data for Melanie Martinez...
# Scraping data for Shawn Mendes...
# Scraping data for Kesha...
# Scraping data for Sia...
# Scraping data for Jessie Murph...
# Scraping data for Gucci Mane...
# Scraping data for The Chainsmokers...
# Scraping data for P!nk...
# Scraping data for My Chemical Romance...
# Scraping data for Camila Cabello...
# Scraping data for The Marías...
# Scraping data for Diplo...
# Scraping data for Don Omar...
# Scraping data for Jack Harlow...
# Scraping data for d4vd...
# Scraping data for Panic! At The Disco...
# Scraping data for Ludacris...
# Scraping data for Bon Iver...
# Scraping data for NewJeans...
# Scraping data for Joji...
# Scraping data for Conan Gray...
# Scraping data for 2 Chainz...
# Scraping data for Pierce The Veil...
# Scraping data for Kehlani...
# Scraping data for LE SSERAFIM...
# Scraping data for Russ...
# Scraping data for Selena Gomez...
# Scraping data for Alicia Keys...
# Scraping data for JID...
# Scraping data for Flo Rida...
# Scraping data for PinkPantheress...
# Scraping data for Weezer...
# Scraping data for Kygo...
# Scraping data for Migos...
# Scraping data for Kevin Gates...
# Scraping data for Manuel Turizo...
# Scraping data for Black Eyed Peas...
# Scraping data for Aventura...
# Scraping data for Lorde...
# Scraping data for Eyedress...
# Scraping data for Tems...
# Scraping data for ABBA...
# Scraping data for Meghan Trainor...
# Scraping data for Warren Zeiders...
# Scraping data for Troye Sivan...
# Scraping data for ERNEST...
# Scraping data for Bebe Rexha...
# Scraping data for Florida Georgia Line...
# Scraping data for The Offspring...
# Scraping data for Tyga...
# Scraping data for Ellie Goulding...
# Scraping data for Avicii...
# Scraping data for Logic...
# Scraping data for T.I....
# Scraping data for Mariah Carey...
# Scraping data for Timbaland...
# Scraping data for Sean Paul...
# Scraping data for Zach Top...
# Scraping data for G-Eazy...
# Scraping data for Faye Webster...
# Scraping data for Madonna...
# Scraping data for ROSALÍA...
# Scraping data for The Cranberries...
# Scraping data for Lewis Capaldi...
# Scraping data for ENHYPEN...
# Scraping data for ScHoolboy Q...
# Scraping data for Nelly...
# Scraping data for Florence + The Machine...
# Scraping data for Connor Price...
# Scraping data for Ski Mask The Slump God...
# Scraping data for Gavin Adcock...
# Scraping data for Jeremih...
# Scraping data for Train...
# Scraping data for Luis Miguel...
# Scraping data for JVKE...
# Scraping data for Avril Lavigne...
# Scraping data for Charlie Puth...
# Scraping data for The Red Clay Strays...
# Scraping data for Chance the Rapper...
# Scraping data for Meek Mill...
# Scraping data for YG...
# Scraping data for blackbear...
# Scraping data for Myles Smith...
# Scraping data for Christina Aguilera...
# Scraping data for Hotel Ugly...
# Scraping data for Mustard...
# Scraping data for Demi Lovato...
# Scraping data for Jason Derulo...
# Scraping data for Gigi Perez...
# Scraping data for Becky G...
# Scraping data for Alex Warren...
# Scraping data for The 1975...
# Scraping data for Ava Max...
# Scraping data for Macklemore...
# Scraping data for wave to earth...
# Scraping data for SEVENTEEN...
# Scraping data for *NSYNC...
# Scraping data for Dolly Parton...
# Scraping data for Zedd...
# Scraping data for Camilo...
# Scraping data for DJ Khaled...
# Scraping data for girl in red...
# Scraping data for Rex Orange County...
# Scraping data for Nelly Furtado...
# Scraping data for Tucker Wetmore...
# Scraping data for DJ Snake...
# Scraping data for Lizzy McAlpine...
# Scraping data for Carrie Underwood...
# Scraping data for Adrianne Lenker...
# Scraping data for Nate Smith...
# Scraping data for Tainy...
# Scraping data for Skrillex...
# Scraping data for Lil Jon...
# Scraping data for Juicy J...
# Scraping data for James Arthur...
# Scraping data for Alec Benjamin...
# Scraping data for Gregory Alan Isakov...
# Scraping data for Sade...
# Scraping data for 5 Seconds of Summer...
# Scraping data for Willie Nelson...
# Scraping data for BLACKPINK...
# Scraping data for Bizarrap...
# Scraping data for The Goo Goo Dolls...
# Scraping data for Måneskin...
# Scraping data for David Kushner...
# Scraping data for The Beach Boys...
# Scraping data for Lost Frequencies...
# Scraping data for TOMORROW X TOGETHER...
# Scraping data for Vance Joy...
# Scraping data for Anitta...
# Scraping data for LISA...
# Scraping data for Labrinth...
# Scraping data for Burna Boy...
# Scraping data for Ella Langley...
# Scraping data for Djo...
# Scraping data for Wizkid...
# Scraping data for John Legend...
# Scraping data for aespa...
# Scraping data for Whitney Houston...
# Scraping data for Bryan Martin...
# Scraping data for Beach House...
# Scraping data for A$AP Ferg...
# Scraping data for Niall Horan...
# Scraping data for Sam Barber...
# Scraping data for Jonas Brothers...
# Scraping data for Tom Odell...
# Scraping data for Enrique Iglesias...
# Scraping data for Gwen Stefani...
# Scraping data for Noah Cyrus...
# Scraping data for Maggie Rogers...
# Scraping data for ILLENIUM...
# Scraping data for Parker McCollum...
# Scraping data for TWICE...
# Scraping data for French Montana...
# Scraping data for Trey Songz...
# Scraping data for Suki Waterhouse...
# Scraping data for Mark Ronson...
# Scraping data for Maná...
# Scraping data for Chance Peña...
# Scraping data for Tinashe...
# Scraping data for Wale...
# Scraping data for Sech...
# Scraping data for JENNIE...
# Scraping data for Kelly Clarkson...
# Scraping data for Tove Lo...
# Scraping data for Natasha Bedingfield...
# Scraping data for The Script...
# Scraping data for Tech N9ne...
# Scraping data for ZAYN...
# Scraping data for Sam Hunt...
# Scraping data for Marc Anthony...
# Scraping data for Prince Royce...
# Scraping data for Ciara...
# Scraping data for Kim Petras...
# Scraping data for Missy Elliott...
# Scraping data for Sebastian Yatra...
# Scraping data for Reik...
# Scraping data for WILLOW...
# Scraping data for Chase Matthew...
# Scraping data for Alesso...
# Scraping data for ATEEZ...
# Scraping data for Rae Sremmurd...
# Scraping data for Men I Trust...
# Scraping data for Mark Ambor...
# Scraping data for B.o.B...
# Scraping data for Rema...
# Scraping data for Backstreet Boys...
# Scraping data for Michael Bublé...
# Scraping data for Wyatt Flores...
# Scraping data for A Day To Remember...
# Scraping data for Anne-Marie...
# Scraping data for Matchbox Twenty...
# Scraping data for Swedish House Mafia...
# Scraping data for Cavetown...
# Scraping data for RAYE...
# Scraping data for Maria Becerra...
# Scraping data for MARINA...
# Scraping data for Marco Antonio Solís...
# Scraping data for Pusha T...
# Scraping data for Remi Wolf...
# Scraping data for Tears For Fears...
# Scraping data for Big Thief...
# Scraping data for Bastille...
# Scraping data for Lauv...
# Scraping data for Omar Apollo...
# Scraping data for Zara Larsson...
# Scraping data for Morat...
# Scraping data for Alok...
# Scraping data for Julia Michaels...
# Scraping data for All Time Low...
# Scraping data for will.i.am...
# Scraping data for Jennifer Lopez...
# Scraping data for Madison Beer...
# Scraping data for Mary J. Blige...
# Scraping data for George Ezra...
# Scraping data for Father John Misty...
# Scraping data for Rise Against...
# Scraping data for Ryan Lewis...
# Scraping data for Clean Bandit...
# Scraping data for Calum Scott...
# Scraping data for Still Woozy...
# Scraping data for Lily-Rose Depp...
# Scraping data for Fetty Wap...
# Scraping data for Sum 41...
# Scraping data for Ashanti...
# Scraping data for Norah Jones...
# Scraping data for Shania Twain...
# Scraping data for Dean Lewis...
# Scraping data for Mazzy Star...
# Scraping data for TLC...
# Scraping data for Jamie Foxx...
# Scraping data for Dove Cameron...
# Scraping data for Martin Garrix...
# Scraping data for Josh Meloy...
# Scraping data for Ovy On The Drums...
# Scraping data for Juan Luis Guerra 4.40...
# Scraping data for Selena...
# Scraping data for The Fray...
# Scraping data for Muscadine Bloodline...
# Scraping data for Bryan Adams...
# Scraping data for Diddy...
# Scraping data for Asake...
# Scraping data for Juan Gabriel...
# Scraping data for Kany García...
# Scraping data for Joyner Lucas...
# Scraping data for Céline Dion...
# Scraping data for The Paper Kites...
# Scraping data for AFROJACK...
# Scraping data for Major Lazer...
# Scraping data for Strawberry Guy...
# Scraping data for The All-American Rejects...
# Scraping data for Alessia Cara...
# Scraping data for Andy Grammer...
# Scraping data for Busta Rhymes...
# Scraping data for AURORA...
# Scraping data for (G)I-DLE...
# Scraping data for Internet Money...
# Scraping data for Nipsey Hussle...
# Scraping data for Addison Rae...
# Scraping data for Dylan Gossett...
# Scraping data for KATSEYE...
# Scraping data for Cults...
# Scraping data for Robin Schulz...
# Scraping data for Aaliyah...
# Scraping data for Sachin-Jigar...
# Scraping data for Danny Ocean...
# Scraping data for Armin van Buuren...
# Scraping data for Magdalena Bay...
# Scraping data for Destiny's Child...
# Scraping data for Lizzo...
# Scraping data for Quinn XCII...
# Scraping data for Corey Kent...
# Scraping data for X Ambassadors...
# Scraping data for benny blanco...
# Scraping data for Blxst...
# Scraping data for Jimmy Eat World...
# Scraping data for Henrik...
# Scraping data for The Game...
# Scraping data for TINI...
# Scraping data for Cuco...
# Scraping data for MEDUZA...
# Scraping data for Soulja Boy...
# Scraping data for Alejandro Fernández...
# Scraping data for Mike Posner...
# Scraping data for Vansire...
# Scraping data for George Michael...
# Scraping data for Macklemore & Ryan Lewis...
# Scraping data for Ado...
# Scraping data for Cordae...
# Scraping data for Keyshia Cole...
# Scraping data for Lucy Dacus...
# Scraping data for Juanes...
# Scraping data for Jason Mraz...
# Scraping data for Shaggy...
# Scraping data for Jacquees...
# Scraping data for Karan Aujla...
# Scraping data for Nic D...
# Scraping data for Counting Crows...
# Scraping data for Wild Rivers...
# Scraping data for Bleachers...
# Scraping data for R3HAB...
# Scraping data for Matt Hansen...
# Scraping data for Enya...
# Scraping data for WALK THE MOON...
# Scraping data for Fitz and The Tantrums...
# Scraping data for ROLE MODEL...
# Scraping data for Duster...
# Scraping data for Jess Glynne...
# Scraping data for Sufjan Stevens...
# Scraping data for James Blake...
# Scraping data for Daya...
# Scraping data for Milky Chance...
# Scraping data for Carly Rae Jepsen...
# Scraping data for Waka Flocka Flame...
# Scraping data for John Denver...
# Scraping data for Pabllo Vittar...
# Scraping data for SiR...
# Scraping data for Beach Bunny...
# Scraping data for Julieta Venegas...
# Scraping data for No Doubt...
# Scraping data for Ricardo Arjona...
# Scraping data for Blood Orange...
# Scraping data for Third Eye Blind...
# Scraping data for Sofia Carson...
# Scraping data for Lloyd...
# Scraping data for Dido...
# Scraping data for Bazzi...
# Scraping data for Tyler Hubbard...
# Scraping data for Emilia...
# Scraping data for The Cars...
# Scraping data for Lupe Fiasco...
# Scraping data for Carlos Vives...
# Scraping data for Sleeping With Sirens...
# Scraping data for Natalia Lafourcade...
# Scraping data for Dave Matthews Band...
# Scraping data for Red Velvet...
# Scraping data for Fergie...
# Scraping data for Orion Sun...
# Scraping data for SYML...
# Scraping data for Ruth B....
# Scraping data for Cyndi Lauper...
# Scraping data for Sean Kingston...
# Scraping data for Diljit Dosanjh...
# Scraping data for Matt Maltese...
# Scraping data for Luis Fonsi...
# Scraping data for a-ha...
# Scraping data for Camila...
# Scraping data for Vampire Weekend...
# Scraping data for Ray Dalton...
# Scraping data for Billy Idol...
# Scraping data for Ana Gabriel...
# Scraping data for Ethel Cain...
# Scraping data for Julien Baker...
# Scraping data for Ja Rule...
# Scraping data for Yuridia...
# Scraping data for Charles Wesley Godwin...
# Scraping data for 24kGoldn...
# Scraping data for The Cardigans...
# Scraping data for KISS OF LIFE...
# Scraping data for Grimes...
# Scraping data for The Mamas & The Papas...
# Scraping data for Josh Ross...
# Scraping data for Zendaya...
# Scraping data for Yot Club...
# Scraping data for Chayanne...
# Scraping data for Heart...
# Scraping data for YOASOBI...
# Scraping data for mike....
# Scraping data for Yseult...
# Scraping data for LANY...
# Scraping data for Duran Duran...
# Scraping data for Kate Bush...
# Scraping data for Keri Hilson...
# Scraping data for Sheryl Crow...
# Scraping data for Udit Narayan...
# Scraping data for Ricky Montgomery...
# Scraping data for Christina Perri...
# Scraping data for Galantis...
# Scraping data for Brandy...
# Scraping data for boygenius...
# Scraping data for Little Mix...
# Scraping data for Ole 60...
# Scraping data for NEEDTOBREATHE...
# Scraping data for Fiona Apple...
# Scraping data for Ana Castela...
# Scraping data for James Bay...
# Scraping data for Nessa Barrett...
# Scraping data for The Outfield...
# Scraping data for IVE...
# Scraping data for 311...
# Scraping data for Kenia OS...
# Scraping data for Keane...
# Scraping data for alt-J...
# Scraping data for Redferrin...
# Scraping data for Dreamville...
# Scraping data for Chris Lake...
# Scraping data for Jon Bellion...
# Scraping data for Steve Aoki...
# Scraping data for NATTI NATASHA...
# Scraping data for Jul...
# Scraping data for Topic...
# Scraping data for Annie Lennox...
# Scraping data for Fabolous...
# Scraping data for FINNEAS...
# Scraping data for Modest Mouse...
# Scraping data for Owl City...
# Scraping data for Mrs. GREEN APPLE...
# Scraping data for Jordana...
# Scraping data for Loud Luxury...
# Scraping data for Of Monsters and Men...
# Scraping data for Zerb...
# Scraping data for Neon Trees...
# Scraping data for Oh Wonder...
# Scraping data for Sixpence None The Richer...
# Scraping data for Tyler Braden...
# Scraping data for Kimbra...
# Scraping data for Lady A...
# Scraping data for GIMS...
# Scraping data for HIXTAPE...
# Scraping data for Becky Hill...
# Scraping data for Kylie Minogue...
# Scraping data for fun....
# Scraping data for Amaarae...
# Scraping data for Bas...
# Scraping data for Ray LaMontagne...
# Scraping data for Rita Ora...
# Scraping data for deadmau5...
# Scraping data for Normani...
# Scraping data for Gryffin...
# Scraping data for BØRNS...
# Scraping data for Daughtry...
# Scraping data for Ha*Ash...
# Scraping data for Gotye...
# Scraping data for Mario...
# Scraping data for Aminé...
# Scraping data for Blondie...
# Scraping data for Marisela...
# Scraping data for Iggy Azalea...
# Scraping data for Zac Efron...
# Scraping data for NCT DREAM...
# Scraping data for CAKE...
# Scraping data for Stellar...
# Scraping data for Carla Morrison...
# Scraping data for Porter Robinson...
# Scraping data for Jay Chou...
# Scraping data for Neil Diamond...
# Scraping data for Lazza...
# Scraping data for Atif Aslam...
# Scraping data for Nicky Youre...
# Scraping data for Alanis Morissette...
# Scraping data for Jessie J...
# Scraping data for Simple Plan...
# Scraping data for Jonas Blue...
# Scraping data for ILLIT...
# Scraping data for Nayer...
# Scraping data for Fat Joe...
# Scraping data for Dimitri Vegas & Like Mike...
# Scraping data for Kenshi Yonezu...
# Scraping data for Kenny Rogers...
# Scraping data for Alejandro Sanz...
# Scraping data for Skylar Grey...
# Scraping data for La Oreja de Van Gogh...
# Scraping data for Kameron Marlowe...
# Scraping data for Dermot Kennedy...
# Scraping data for Felix Jaehn...
# Scraping data for Sleeping At Last...
# Scraping data for Joel Corry...
# Scraping data for Good Charlotte...
# Scraping data for Fireboy DML...
# Scraping data for Smash Mouth...
# Scraping data for Oliver Anthony Music...
# Scraping data for Ryan Mack...
# Scraping data for LECADE...
# Scraping data for The Temper Trap...
# Scraping data for Matheus & Kauan...
# Scraping data for Ginuwine...
# Scraping data for Tori Kelly...
# Scraping data for GRAHAM...
# Scraping data for Tanishk Bagchi...
# Scraping data for Jessie Reyez...
# Scraping data for j-hope...
# Scraping data for Los Enanitos Verdes...
# Scraping data for Cocteau Twins...
# Scraping data for Lykke Li...
# Scraping data for Chri$tian Gate$...
# Scraping data for Jeremy Zucker...
# Scraping data for Livingston...
# Scraping data for Ella Henderson...
# Scraping data for The Head And The Heart...
# Scraping data for Wham!...
# Scraping data for Jesse & Joy...
# Scraping data for Fleet Foxes...
# Scraping data for The-Dream...
# Scraping data for Bayker Blankenship...
# Scraping data for Two Feet...
# Scraping data for Taio Cruz...
# Scraping data for Janet Jackson...
# Scraping data for Men At Work...
# Scraping data for Sugar Ray...
# Scraping data for Brandi Carlile...
# Scraping data for Rick Springfield...
# Scraping data for AP Dhillon...
# Scraping data for VOILÀ...
# Scraping data for Timmy Trumpet...
# Scraping data for XG...
# Scraping data for Dave Stewart...
# Scraping data for Lauren Spencer Smith...
# Scraping data for Ke Personajes...
# Scraping data for Death Cab for Cutie...
# Scraping data for Gym Class Heroes...
# Scraping data for Kelly Rowland...
# Scraping data for FLETCHER...
# Scraping data for BABYMONSTER...
# Scraping data for Sara Bareilles...
# Scraping data for Her's...
# Scraping data for Eurythmics...
# Scraping data for MØ...
# Scraping data for Taking Back Sunday...
# Scraping data for The Pussycat Dolls...
# Scraping data for Hot Mulligan...
# Scraping data for Ricky Martin...
# Scraping data for Phoenix...
# Scraping data for Paris Paloma...
# Scraping data for Vishal Mishra...
# Scraping data for Yellowcard...
# Scraping data for Kenny Loggins...
# Scraping data for Glee Cast...
# Scraping data for 112...
# Scraping data for Hailee Steinfeld...
# Scraping data for W&W...
# Scraping data for Vitamin String Quartet...
# Scraping data for Davido...
# Scraping data for Sin Bandera...
# Scraping data for Conway Twitty...
# Scraping data for Cher...
# Scraping data for IU...
# Scraping data for Hootie & The Blowfish...
# Scraping data for Andrea Bocelli...
# Scraping data for Lamp...
# Scraping data for Kaskade...
# Scraping data for George Jones...
# Scraping data for Sidhu Moose Wala...
# Scraping data for Sting...
# Scraping data for Yeah Yeah Yeahs...
# Scraping data for Bryce Vine...
# Scraping data for Dream, Ivory...
# Scraping data for Colbie Caillat...
# Scraping data for Will Smith...
# Scraping data for Lindsey Stirling...
# Scraping data for MAX...
# Scraping data for Piso 21...
# Scraping data for 3OH!3...
# Scraping data for CeeLo Green...
# Scraping data for Pablo Alborán...
# Scraping data for Hugo & Guilherme...
# Scraping data for Ian Munsick...
# Scraping data for Spice Girls...
# Scraping data for Del Water Gap...
# Scraping data for LUDMILLA...
# Scraping data for Olivia Dean...
# Scraping data for The National...
# Scraping data for Passenger...
# Scraping data for Jax Jones...
# Scraping data for Haze...
# Scraping data for Leo Dan...
# Scraping data for Roxette...
# Scraping data for Asking Alexandria...
# Scraping data for Tones And I...
# Scraping data for Ninho...
# Scraping data for Eve...
# Scraping data for Juicy Luicy...
# Scraping data for Looking Glass...
# Scraping data for Selena Gomez & The Scene...
# Scraping data for Iron & Wine...
# Scraping data for Icona Pop...
# Scraping data for Snow Patrol...
# Scraping data for Coco Jones...
# Scraping data for Baby Bash...
# Scraping data for Flawed Mangoes...
# Scraping data for Imanbek...
# Scraping data for Lukas Graham...
# Scraping data for Jay Webb...
# Scraping data for INXS...
# Scraping data for Darshan Raval...
# Scraping data for Geolier...
# Scraping data for Rocío Dúrcal...
# Scraping data for charlieonnafriday...
# Scraping data for Dr. Dog...
# Scraping data for Alphaville...
# Scraping data for Hombres G...
# Scraping data for Juelz Santana...
# Scraping data for Filipe Ret...
# Scraping data for Uncle Kracker...
# Scraping data for Lit...
# Scraping data for Lifehouse...
# Scraping data for The Red Jumpsuit Apparatus...
# Scraping data for FIFTY FIFTY...
# Scraping data for Tiakola...
# Scraping data for Ofenbach...
# Scraping data for Frankie Valli...
# Scraping data for Shiva...
# Scraping data for The Used...
# Scraping data for Yebba...
# Scraping data for St. Vincent...
# Scraping data for LMFAO...
# Scraping data for Sage The Gemini...
# Scraping data for Fujii Kaze...
# Scraping data for Birdy...
# Scraping data for Sfera Ebbasta...
# Scraping data for Young Money...
# Scraping data for NCT 127...
# Scraping data for Gloria Trevi...
# Scraping data for Gente De Zona...
# Scraping data for ITZY...
# Scraping data for John Newman...
# Scraping data for Mandy Moore...
# Scraping data for Seven Lions...
# Scraping data for Fifth Harmony...
# Scraping data for Beartooth...
# Scraping data for Collective Soul...
# Scraping data for Melendi...
# Scraping data for Nancy Sinatra...
# Scraping data for Bowling For Soup...
# Scraping data for SWV...
# Scraping data for The Shins...
# Scraping data for NMIXX...
# Scraping data for Nick Jonas...
# Scraping data for Huey Lewis & The News...
# Scraping data for Cassie...
# Scraping data for Emei...
# Scraping data for The Last Dinner Party...
# Scraping data for Pat Benatar...
# Scraping data for BINI...
# Scraping data for Sam Feldt...
# Scraping data for Toro y Moi...
# Scraping data for Lil' Kim...
# Scraping data for Kid Ink...
# Scraping data for Frankie Valli & The Four Seasons...
# Scraping data for Jervis Campbell...
# Scraping data for Deorro...
# Scraping data for Hoobastank...
# Scraping data for Jay Sean...
# Scraping data for Monica...
# Scraping data for Tai Verdes...
# Scraping data for BOYNEXTDOOR...
# Scraping data for Hoodie Allen...
# Scraping data for Bomba Estéreo...
# Scraping data for Kenya Grace...
# Scraping data for The Piano Guys...
# Scraping data for Bea Miller...
# Scraping data for Don Diablo...
# Scraping data for James Hype...
# Scraping data for Jaden...
# Scraping data for Escape the Fate...
# Scraping data for D.O.D...
# Scraping data for mxmtoon...
# Scraping data for Lauana Prado...
# Scraping data for Luísa Sonza...
# Scraping data for Brando...
# Scraping data for DNCE...
# Scraping data for Bonnie Tyler...
# Scraping data for Mase...
# Scraping data for MKTO...
# Scraping data for Far East Movement...
# Scraping data for Louis The Child...
# Scraping data for Atlus...
# Scraping data for AFI...
# Scraping data for MAGIC!...
# Scraping data for The Japanese House...
# Scraping data for American Authors...
# Scraping data for Kungs...
# Scraping data for ANNA...
# Scraping data for Jaani...
# Scraping data for Slowdive...
# Scraping data for The xx...
# Scraping data for Jazmine Sullivan...
# Scraping data for ヨルシカ...
# Scraping data for KYLE...
# Scraping data for Franco De Vita...
# Scraping data for Plain White T's...
# Scraping data for Kacy Hill...
# Scraping data for Sub Urban...
# Scraping data for Cheat Codes...
# Scraping data for Kidd G...
# Scraping data for Hayley Williams...
# Scraping data for Carlos Rivera...
# Scraping data for EXO...
# Scraping data for Natalie Jane...
# Scraping data for Pentatonix...
# Scraping data for Dimitri Vegas...
# Scraping data for Dhruv...
# Scraping data for The Oh Hellos...
# Scraping data for Seeb...
# Scraping data for Sir Chloe...
# Scraping data for The Foundations...
# Scraping data for Grey...
# Scraping data for Vincent Mason...
# Scraping data for Lily Allen...
# Scraping data for The Story So Far...
# Scraping data for Iyaz...
# Scraping data for Sheck Wes...
# Scraping data for JAWNY...
# Scraping data for Sophie Ellis-Bextor...
# Scraping data for Of Mice & Men...
# Scraping data for AYLIVA...
# Scraping data for AWOLNATION...
# Scraping data for BENEE...
# Scraping data for Semicenk...
# Scraping data for Penelope Scott...
# Scraping data for Rudimental...
# Scraping data for Jamiroquai...
# Scraping data for Young Stoner Life...
# Scraping data for Belinda...
# Scraping data for BAEKHYUN...
# Scraping data for Regard...
# Scraping data for Ashley Cooke...
# Scraping data for JIN...
# Scraping data for Black Veil Brides...
# Scraping data for Arcade Fire...
# Scraping data for DAY6...
# Scraping data for Dylan Marlowe...
# Scraping data for Chayce Beckham...
# Scraping data for Kyle Hume...
# Scraping data for Julio Iglesias...
# Scraping data for Olivia O'Brien...
# Scraping data for Soft Cell...
# Scraping data for Pecos & the Rooftops...
# Scraping data for Conner Smith...
# Scraping data for NAYEON...
# Scraping data for Faith Evans...
# Scraping data for Kodaline...
# Scraping data for Victony...
# Scraping data for RADWIMPS...
# Scraping data for Cooper Alan...
# Scraping data for Indila...
# Scraping data for KC & The Sunshine Band...
# Scraping data for Blind Melon...
# Scraping data for P1Harmony...
# Scraping data for Laura Pausini...
# Scraping data for FKA twigs...
# Scraping data for Glen Campbell...
# Scraping data for Simple Minds...
# Scraping data for Bobby V....
# Scraping data for Ella Eyre...
# Scraping data for Chris Webby...
# Scraping data for Pedro Capó...
# Scraping data for ZEROBASEONE...
# Scraping data for Jay Park...
# Scraping data for Carole King...
# Scraping data for Sonny Fodera...
# Scraping data for Austin Williams...
# Scraping data for MNEK...
# Scraping data for August Alsina...
# Scraping data for Memphis May Fire...
# Scraping data for Sigala...
# Scraping data for Teyana Taylor...
# Scraping data for Corinne Bailey Rae...
# Scraping data for Jaymes Young...
# Scraping data for Elyanna...
# Scraping data for Oliver Heldens...
# Scraping data for The Sundays...
# Scraping data for Kizz Daniel...
# Scraping data for The Monkees...
# Scraping data for Starship...
# Scraping data for Maisie Peters...
# Scraping data for Rob Thomas...
# Scraping data for Mahalini...
# Scraping data for Stromae...
# Scraping data for Jet...
# Scraping data for Cristian Castro...
# Scraping data for Loco...
# Scraping data for Jessica Pratt...
# Scraping data for Boza...
# Scraping data for Eric Bellinger...
# Scraping data for K.Flay...
# Scraping data for We Came As Romans...
# Scraping data for RIIZE...
# Scraping data for Aitana...
# Scraping data for Why Don't We...
# Scraping data for Barenaked Ladies...
# Scraping data for Seafret...
# Scraping data for Rahat Fateh Ali Khan...
# Scraping data for Ace of Base...
# Scraping data for JACKBOYS...
# Scraping data for Guilherme & Benuto...
# Scraping data for Elvis Crespo...
# Scraping data for Mayday Parade...
# Scraping data for Vaundy...
# Scraping data for Tamia...
# Scraping data for JP Saxe...
# Scraping data for Panchiko...
# Scraping data for Ben Rector...
# Scraping data for Fonseca...
# Scraping data for Hannah Montana...
# Scraping data for BIBI...
# Scraping data for Pet Shop Boys...
# Scraping data for MK...
# Scraping data for FAST BOY...
# Scraping data for Creepy Nuts...
# Scraping data for Regina Spektor...
# Scraping data for Robin Thicke...
# Scraping data for LiSA...
# Scraping data for ONE OK ROCK...
# Scraping data for Sammie...
# Scraping data for Jack Stauber...
# Scraping data for The La Planta...
# Scraping data for Mackenzy Mackay...
# Scraping data for SDM...
# Scraping data for Morray...
# Scraping data for Arizona Zervas...
# Scraping data for Gavin DeGraw...
# Scraping data for SAULT...
# Scraping data for Underoath...
# Scraping data for Mel McDaniel...
# Scraping data for Thalia...
# Scraping data for Mau y Ricky...
# Scraping data for Salt-N-Pepa...
# Scraping data for Pavement...
# Scraping data for Hindia...
# Scraping data for BOYS LIKE GIRLS...
# Scraping data for Lil Pump...
# Scraping data for We The Kings...
# Scraping data for Queen Naija...
# Scraping data for Bruno Major...
# Scraping data for Lil Dicky...
# Scraping data for Everclear...
# Scraping data for Kiki Dee...
# Scraping data for Edward Maya...
# Scraping data for Dillon Francis...
# Scraping data for Big Time Rush...
# Scraping data for Arash...
# Scraping data for Grouper...
# Scraping data for Nothing But Thieves...
# Scraping data for The Home Team...
# Scraping data for INNA...
# Scraping data for CHVRCHES...
# Scraping data for Werenoi...
# Scraping data for Cedric Gervais...
# Scraping data for Miguel Bosé...
# Scraping data for Wheatus...
# Scraping data for Café Tacvba...
# Scraping data for Bnxn...
# Scraping data for Griff...
# Scraping data for Emmanuel...
# Scraping data for Belanova...
# Scraping data for cassö...
# Scraping data for Dennis Lloyd...
# Scraping data for Live...
# Scraping data for Tayc...
# Scraping data for Maiara & Maraisa...
# Scraping data for back number...
# Scraping data for Aya Nakamura...
# Scraping data for Benny Benassi...
# Scraping data for Dadju...
# Scraping data for B Praak...
# Scraping data for The Ronettes...
# Scraping data for Robyn...
# Scraping data for Chinmayi...
# Scraping data for Gazo...
# Scraping data for Tom Misch...
# Scraping data for Ruel...
# Scraping data for Jarabe De Palo...
# Scraping data for Neck Deep...
# Scraping data for DDG...
# Scraping data for Don Williams...
# Scraping data for Omarion...
# Scraping data for Waterparks...
# Scraping data for David Morris...
# Scraping data for Toni Braxton...
# Scraping data for Larry Fleet...
# Scraping data for Phillip Phillips...
# Scraping data for New Found Glory...
# Scraping data for Brand New...
# Scraping data for Hopsin...
# Scraping data for Tulus...
# Scraping data for Movements...
# Scraping data for Band of Horses...
# Scraping data for PLK...
# Scraping data for Portishead...
# Scraping data for The Wanted...
# Scraping data for Alexander Stewart...
# Scraping data for Alejandra Guzman...
# Scraping data for Channel Tres...
# Scraping data for YEONJUN...
# Scraping data for John Martin...
# Scraping data for Riton...
# Scraping data for Alvvays...
# Scraping data for Yoke Lore...
# Scraping data for BETWEEN FRIENDS...
# Scraping data for José González...
# Scraping data for Jerry Rivera...
# Scraping data for Guè...
# Scraping data for Colby Acuff...
# Scraping data for Blues Traveler...
# Scraping data for Vika Jigulina...
# Scraping data for La Quinta Estacion...
# Scraping data for Hikaru Utada...
# Scraping data for EDEN...
# Scraping data for NOTD...
# Scraping data for Richard Marx...
# Scraping data for Anuv Jain...
# Scraping data for Manuel Medrano...
# Data saved to spotify_data.csv
